# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy  as np
import pandas as pd
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
from sklearn import linear_model
from sklearn.linear_model import LassoCV
from sklearn.model_selection import cross_val_score
plt.style.use('ggplot')
# %matplotlib inline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")
import pickle as pk

# %%
scores = [0.1379, 0.1354,0.1352, 0.1533,0.1532, 0.1497, 0.1449, 0.1486,
         0.1533, 0.1497,0.1201,0.13671, 0.1486,0.1497, 0.1449,
         0.1358, 0.1283, 0.1219, 0.12193,
         0.1265, 0.1311,0.1226, 0.1207,0.1373,
         0.1232, 0.1208 , 0.1212, 0.1256, 0.12081, 0.1189, 0.1190,0.1176, 0.1175, 0.1172, 0.1169]

# %%
scores_ridge = [0.1379, 0.13525, 0.1283, 0.1311, 0.1201 ,0.1263,
                0.1290, 0.1203,0.12706]

# %%
scores_lasso = [0.1367, 0.1358, 0.1354,0.1219, 0.1265,
               0.1219, 0.1232,0.1212, 0.1203,0.1208, 0.1212, 0.1226, 0.1189, 0.1373, 0.1190]

# %%
score_xgBoost = [0.1256]

# %%
score_stacked = [0.1179]

# %%
score_rf = [0.1532, 0.1533, 0.1497, 0.1449, 0.1486]

# %%
best_scores = pd.DataFrame({"Model": ['Ridge', "Lasso", "XGB", "Random Forrest", "Stacked Model"],
                            "Best Score": [min(scores_ridge), min(scores_lasso), min(score_xgBoost), min(score_rf),
                                          min(score_stacked)]})
best_scores.to_csv('best_model_scores.csv', index = False)

# %%
plt.tick_params(axis = 'both', labelsize = 15, grid_color = 'white', )
plt.rcParams['figure.figsize'] = (20,12)
plt.plot(scores)
plt.ylabel('some numbers')
plt.ylim(0.11,0.16)
plt.title('Kaggle Score per Submission',size = 25)
plt.xlabel('Submissions',size = 15)
plt.ylabel('RMSE',size = 15)
from matplotlib import pyplot as mp
mp.savefig('foo.png')
